# %%
import pandas as pd
import numpy as np
import datetime
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('files_for_lab/learningSet.csv')

# %% [markdown]
# Lab | Revisiting Machine Learning Case Study
#
# - In this lab, you will use `learningSet.csv` file which you already have cloned in today's activities.
#
# ### Instructions
#
# Complete the following steps on the categorical columns in the dataset:
#
# - Check for null values in all the columns
# - Exclude the following variables by looking at the definitions. Create a new empty list called `drop_list`. We will append this list and then drop all the columns in this list later:
#     - `OSOURCE` - symbol definitions not provided, too many categories
#     - `ZIP CODE` - we are including state already
# - Identify columns that over 85% missing values
# - Remove those columns from the dataframe
# - Reduce the number of categories in the column `GENDER`. The column should only have either "M" for males, "F" for females, and "other" for all the rest
#     - Note that there are a few null values in the column. We will first replace those null values using the code below:
#
#     ```python
#     print(categorical['GENDER'].value_counts())
#     categorical['GENDER'] = categorical['GENDER'].fillna('F')
#     ```

# %%
data.shape
# Out:
# (95412, 481)

# %%
data.describe()
# Out:
#             ODATEDW         TCODE           DOB           AGE       NUMCHLD  \
# count  95412.000000  95412.000000  95412.000000  71747.000000  12386.000000
# mean    9141.363256     54.223117   2723.602933     61.611649      1.527773
# std      343.454752    953.844476   2132.241295     16.664199      0.806861
# min     8306.000000      0.000000      0.000000      1.000000      1.000000
# 25%     8801.000000      0.000000    201.000000     48.000000      1.000000
# 50%     9201.000000      1.000000   2610.000000     62.000000      1.000000
# 75%     9501.000000      2.000000   4601.000000     75.000000      2.000000
# max     9701.000000  72002.000000   9710.000000     98.000000      7.000000
#
#              INCOME       WEALTH1           HIT       MBCRAFT      MBGARDEN  \
# count  74126.000000  50680.000000  95412.000000  42558.000000  42558.000000
# mean       3.886248      5.345699      3.321438      0.152075      0.059166
# ...

# %%
catCols=data.select_dtypes("object").columns
catCols= list(set(catCols))
catCols
# Out:
# ['CATLG',
#  'MAJOR',
#  'RFA_21',
#  'PCOWNERS',
#  'BIBLE',
#  'GENDER',
#  'RFA_18',
#  'RECPGVG',
#  'RECINHSE',
#  'CHILD12',
#  'PVASTATE',
#  'NOEXCH',
#  'RFA_2R',
#  'PLATES',
#  'CRAFTS',
#  'CHILD03',
#  'SOLIH',
#  'RFA_9',
#  'RFA_6',
#  'RFA_22',
#  'MAILCODE',
#  'RFA_10',
#  'STATE',
#  'CDPLAY',
#  'DATASRCE',
#  'OSOURCE',
#  'WALKER',
#  'RFA_24',
#  'PEPSTRFL',
#  'RFA_11',
#  'HOMEOWNR',
#  'KIDSTUFF',
#  'COLLECT1',
#  'RECSWEEP',
#  'RFA_4',
#  'VETERANS',
#  'RFA_16',
#  'CARDS',
#  'MDMAUD_F',
#  'RFA_2',
#  'ZIP',
#  'GEOCODE2',
#  'RFA_3',
#  'BOATS',
#  'RFA_14',
#  'RFA_20',
#  'RFA_17',
#  'LIFESRC',
#  'FISHER',
#  'RFA_2A',
#  'RECP3',
#  'MDMAUD_R',
#  'GEOCODE',
#  'PHOTO',
#  'RFA_15',
#  'RFA_5',
#  'RFA_12',
#  'MDMAUD',
#  'RFA_13',
#  'SOLP3',
#  'DOMAIN',
#  'PETS',
#  'HOMEE',
#  'MDMAUD_A',
#  'RFA_7',
#  'RFA_19',
#  'AGEFLAG',
#  'RFA_8',
#  'RFA_23',
#  'CHILD07',
#  'CLUSTER',
#  'CHILD18',
#  'GARDENIN',
#  'STEREO']

# %%
dataCat=data[catCols]

# %%
for x in dataCat['MAJOR']:
    if x ==' ':
        print('empty')
# Out:
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# empty
# ...

# %%
NullList=[]
for col in dataCat.columns:
    if dataCat[col].isna().sum()>0:
        NullList.append(col)
    else:
        continue
print (NullList)
# Out:
# ['GEOCODE2']

# %%
dataCat['GEOCODE2'].isna().sum()
# Out:
# 132

# %%
drop_list=[]
drop_list_data=[]

# %%
for col in dataCat.columns:
    count=0
    for x in dataCat[col]:
        if x == ' ':
            count=count+1
        else:
            continue
    #print(col,count/len(dataCat))
    if count/len(dataCat)>0.85:
        print(col,count/len(dataCat))
        drop_list.append(col)
        dataCat=dataCat.drop(col, axis=1)
    else:
        continue
    drop_Data=data[drop_list]
# Out:
# CATLG 0.9175680207940301
# MAJOR 0.9969186265878506
# PCOWNERS 0.890150085943068
# BIBLE 0.9070242736762671
# RECPGVG 0.9988051817381461
# RECINHSE 0.9297467823753826
# CHILD12 0.9810191590156374
# PVASTATE 0.9847189032826059
# PLATES 0.9941307173101915
# CRAFTS 0.9143084727287972
# CHILD03 0.9879889322097849
# SOLIH 0.935018655934264
# MAILCODE 0.9853372741374251
# CDPLAY 0.8715675177126567
# WALKER 0.8899404687041462
# KIDSTUFF 0.9839013960508112
# COLLECT1 0.9454785561564583
# RECSWEEP 0.9830524462331782
# VETERANS 0.8907265333501028
# CARDS 0.989089422714124
# BOATS 0.9787448119733367
# FISHER 0.9252714543244036
# RECP3 0.9788601014547437
# PHOTO 0.9498385947260303
# SOLP3 0.9981134448497044
# HOMEE 0.9907034754538213
# CHILD07 0.9835869701924286
# CHILD18 0.9701609860394919
# GARDENIN 0.8595354881985494
# STEREO 0.86590785226177

# %%
drop_Data
# Out:
#       CATLG MAJOR PCOWNERS BIBLE RECPGVG RECINHSE CHILD12 PVASTATE PLATES  \
# 0
# 1
# 2
# 3
# 4         Y                    Y                X
# ...     ...   ...      ...   ...     ...      ...     ...      ...    ...
# 95407
# 95408
# 95409
# 95410                                           X
# 95411           X                      X        X
#
#       CRAFTS  ... BOATS FISHER RECP3 PHOTO SOLP3 HOMEE CHILD07 CHILD18  \
# 0             ...
# 1             ...                                                    M
# 2             ...
# 3             ...
# 4          Y  ...                  X
# ...      ...  ...   ...    ...   ...   ...   ...   ...     ...     ...
# 95407         ...
# 95408         ...                                                    M
# 95409         ...                  X
# 95410         ...
# 95411         ...
#
#       GARDENIN STEREO
# 0
# 1
# 2
# 3
# 4            Y      Y
# ...        ...    ...
# 95407
# 95408
# 95409
# 95410
# 95411
#
# ...

# %%
dataCat.columns
# Out:
# Index(['RFA_21', 'GENDER', 'RFA_18', 'NOEXCH', 'RFA_2R', 'RFA_9', 'RFA_6',
#        'RFA_22', 'RFA_10', 'STATE', 'DATASRCE', 'OSOURCE', 'RFA_24',
#        'PEPSTRFL', 'RFA_11', 'HOMEOWNR', 'RFA_4', 'RFA_16', 'MDMAUD_F',
#        'RFA_2', 'ZIP', 'GEOCODE2', 'RFA_3', 'RFA_14', 'RFA_20', 'RFA_17',
#        'LIFESRC', 'RFA_2A', 'MDMAUD_R', 'GEOCODE', 'RFA_15', 'RFA_5', 'RFA_12',
#        'MDMAUD', 'RFA_13', 'DOMAIN', 'PETS', 'MDMAUD_A', 'RFA_7', 'RFA_19',
#        'AGEFLAG', 'RFA_8', 'RFA_23', 'CLUSTER'],
#       dtype='object')

# %%
len(catCols)-len(dataCat.columns)== len(drop_list) #just to check if all dropped cloumns are 
#stored
# Out:
# True

# %%
dataCat['OSOURCE']
len(dataCat['ZIP'].unique())
# Out:
# 19938

# %%
drop_Data= pd.concat([drop_Data, dataCat[['OSOURCE','ZIP']]], axis=1)

# %%
drop_Data.columns
# Out:
# Index(['CATLG', 'MAJOR', 'PCOWNERS', 'BIBLE', 'RECPGVG', 'RECINHSE', 'CHILD12',
#        'PVASTATE', 'PLATES', 'CRAFTS', 'CHILD03', 'SOLIH', 'MAILCODE',
#        'CDPLAY', 'WALKER', 'KIDSTUFF', 'COLLECT1', 'RECSWEEP', 'VETERANS',
#        'CARDS', 'BOATS', 'FISHER', 'RECP3', 'PHOTO', 'SOLP3', 'HOMEE',
#        'CHILD07', 'CHILD18', 'GARDENIN', 'STEREO', 'OSOURCE', 'ZIP'],
#       dtype='object')

# %%
dataCat=dataCat.drop(['OSOURCE','ZIP'], axis=1)

# %%
print(dataCat['GENDER'].value_counts())
dataCat['GENDER'] = dataCat['GENDER'].fillna('F')
# Out:
# F    51277
# M    39094
#       2957
# U     1715
# J      365
# A        2
# C        2
# Name: GENDER, dtype: int64

# %%
print(dataCat['GENDER'].value_counts())
# Out:
# F    51277
# M    39094
#       2957
# U     1715
# J      365
# A        2
# C        2
# Name: GENDER, dtype: int64

# %%
dataCat['GENDER'] = dataCat['GENDER'].apply(lambda x: 'F' if x == ' ' else x)
# empty entries of Gender should be replaced by 'F'

# %%
print(dataCat['GENDER'].value_counts())
# Out:
# F    54234
# M    39094
# U     1715
# J      365
# A        2
# C        2
# Name: GENDER, dtype: int64

# %%
dataCat['GENDER'] = dataCat['GENDER'].apply(lambda x: 'other' if x == 'U' or x == 'J' or x == 'A' or x== 'C' else x)

# %%
print(dataCat['GENDER'].value_counts())
# Out:
# F        54234
# M        39094
# other     2084
# Name: GENDER, dtype: int64
